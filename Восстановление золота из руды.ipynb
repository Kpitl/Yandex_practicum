# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Кирилл, привет!👋</b>
#
# Меня зовут Алексей Гриб, и я буду ревьюером твоего проекта.
#
# Сразу хочу предложить в дальнейшем общаться на "ты" - надеюсь, так будет комфортнее:) Но если это неудобно, обязательно дай знать, и мы придумаем что-нибудь ещё!
#
# Цель ревью - не искать ошибки в твоём проекте, а помочь тебе сделать твою работу ещё лучше, устранив недочёты и приблизив её к реальным задачам аналитика. Поэтому не расстраивайся, если что-то не получилось с первого раза - это нормально, и это поможет тебе вырасти!
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> похвала, рекомендации «со звёздочкой», полезные лайфхаки, которые сделают и без того красивое решение ещё более элегантным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> некритичные ошибки или развивающие рекомендации на будущее.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Критичные ошибки, которые обязательно нужно исправить.
# </div>
#
# Я не смогу принять проект, если в нём будет хотя бы одна критичная ошибка или несколько некритичных ошибок - тогда проект нужно будет немного доработать. Но это нестрашно - я обязательно дам тебе подсказку или укажу верное направление.
#
# Пожалуйста, не удаляй мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Ты также можешь задавать свои вопросы, реагировать на мои комментарии, делать пометки и пояснения - полная творческая свобода! Но маленькая просьба - пускай они будут отличаться от моих комментариев, это поможет избежать путаницы в нашем общении:)
# Например, вот так:
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *твой текст*
# </div>
#
# Давай посмотрим на твой проект!

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера 10.01 (без проверки) <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Я вижу, исполнение твоего кода начинается в ячейке с номером, который отличается от единицы. Также в конце проекта ячейка с тестированием итоговой модели не выполнена, выведено сообщение об ошибке.
#
# Перед отправкой проекта стоит проверять работоспособность кода — это можно сделать, нажав на панели Jupiter Hub ``Kernel`` и ``Restart & Run All`` (см скриншот ниже).
#
# ![](https://i.postimg.cc/yd19rYf6/Screenshot-428.png)
#
# Важно также убедиться, что все ячейки проекта исполнились - можно просто пролистать работу до конца и убедиться, что последняя ячейка исполнена. Такая проверка поможет тебе убедиться, что твоё решение будет должным образом воспроизведено во время ревью или во время передачи его заказчику - это очень важный этап, пренебрегать которым не стоит:)
#
# Пожалуйста, убедись, что проект работает, перед его отправкой на ревью. Если есть сложности - обратись к преподавателю по проектам или оставь вопросы для меня в комментариях, и я постараюсь направить в нужную сторону.
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Все ячейки с кодом работают нормально</div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Теперь порядок!

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Нахождение-MAE-между-полученными-расчётами-и-значением-признака" data-toc-modified-id="Нахождение-MAE-между-полученными-расчётами-и-значением-признака-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Нахождение MAE между полученными расчётами и значением признака</a></span></li><li><span><a href="#Анализ-признаков,-недоступные-тестовой-выборки" data-toc-modified-id="Анализ-признаков,-недоступные-тестовой-выборки-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Анализ признаков, недоступные тестовой выборки</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изменения-концентрации-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки" data-toc-modified-id="Изменения-концентрации-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Изменения концентрации металлов (Au, Ag, Pb) на различных этапах очистки</a></span></li><li><span><a href="#Сравнение-распределения-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках" data-toc-modified-id="Сравнение-распределения-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Сравнение распределения размеров гранул сырья на обучающей и тестовой выборках</a></span></li><li><span><a href="#Исследование-суммарной-концентрации-всех-веществ-на-разных-стадиях" data-toc-modified-id="Исследование-суммарной-концентрации-всех-веществ-на-разных-стадиях-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Исследование суммарной концентрации всех веществ на разных стадиях</a></span></li></ul></li><li><span><a href="#Модель" data-toc-modified-id="Модель-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Модель</a></span><ul class="toc-item"><li><span><a href="#Функция-для-вычисления-итоговой-sMAPE" data-toc-modified-id="Функция-для-вычисления-итоговой-sMAPE-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Функция для вычисления итоговой sMAPE</a></span></li><li><span><a href="#Разделение-данных" data-toc-modified-id="Разделение-данных-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Разделение данных</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Подготовьте прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Вам нужно:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.
#
# Чтобы выполнить проект, обращайтесь к библиотекам *pandas*, *matplotlib* и *sklearn.* Вам поможет их документация.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Прекрасное вступление!
#
# В нём есть всё, что необходимо, чтобы понять суть проекта с первых строк отчёта!
#
# Спасибо, что есть оглавление в плагине toc и в виде гиперссылок - по проекту удобно перемещаться:)

# %% [markdown]
# ## Подготовка данных

# %%
# Импортируем необходимы библиотеки
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, make_scorer
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.dummy import DummyRegressor
from numpy.random import RandomState

pd.set_option('display.max_rows', 10)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Библиотеки импортировали - отлично! Спасибо, что перезапускаешь проект перед отправкой на ревью - это важный шаг, который поможет избежать простых и досадных ошибок при воспроизведении решнеия:)
# </div>

# %%
# Выгрузим данные и изучим признаки
try:
    train_df = pd.read_csv('/datasets/gold_recovery_train_new.csv')
    test_df = pd.read_csv('/datasets/gold_recovery_test_new.csv') 
    full_df = pd.read_csv('/datasets/gold_recovery_full_new.csv')
except:
    train_df = pd.read_csv('gold_recovery_train_new.csv')
    test_df = pd.read_csv('gold_recovery_test_new.csv')
    full_df = pd.read_csv('gold_recovery_full_new.csv')
    
# Выводем пять первых и последних столбцов датафрейма
display(train_df)
display(test_df)
display(full_df)
# Out:
#                       date  final.output.concentrate_ag  \
# 0      2016-01-15 00:00:00                     6.055403
# 1      2016-01-15 01:00:00                     6.029369
# 2      2016-01-15 02:00:00                     6.055926
# 3      2016-01-15 03:00:00                     6.047977
# 4      2016-01-15 04:00:00                     6.148599
# ...                    ...                          ...
# 14144  2018-08-18 06:59:59                     3.224920
# 14145  2018-08-18 07:59:59                     3.195978
# 14146  2018-08-18 08:59:59                     3.109998
# 14147  2018-08-18 09:59:59                     3.367241
# 14148  2018-08-18 10:59:59                     3.598375
#
#        final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                         9.889648                      5.507324
# 1                         9.968944                      5.257781
# 2                        10.213995                      5.383759
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>
#
# Данные загрузили.
#
# При считывании данных из файла здорово перестраховывать себя от ошибок, связанных, например, с неверным указанием пути к файлу. А иногда бывает, что работаешь с файлом локально, выгружаешь его на сервер, ожидая, что он будет принимать данные, которые лежат на том же сервере, а код падает с ошибкой, потому что путь к файлу не поменялся с локального на серверный.
#
# Для этого, например, можно использовать конструкцию `try-except`: сначала пробуешь локальный путь, при возникновении ошибки используется серверный путь (подробнее можешь почитать тут: https://pythonworld.ru/tipy-dannyx-v-python/isklyucheniya-v-python-konstrukciya-try-except-dlya-obrabotki-isklyuchenij.html).
#
# Но еще лучше использовать библиотеку `os` - её использование позволит тебе отойти от прописывания путей к файлу (а локальные директории могут меняться часто в зависимости от пользователя) и перейти к автоматическому определению пути к файлу с помощью модуля `path`. Как пример:
#
#     import os
#
#     pth1 = '/folder_1/data.csv'
#     pth2 = '/folder_2/data.csv'
#
#     if os.path.exists(pth1):
#         query_1 = pd.read_csv(pth1)
#     elif os.path.exists(pth2):
#         query_1 = pd.read_csv(pth2)
#     else:
#         print('Something is wrong')
#
# В нём мы указываем только непосредственно директорию с файлом, а уже путь к ней модуль `path` определит самостоятельно.
#
# Также ещё на этапе считывания данных можно спарсить дату: за это действие отвечает параметр `parse_dates` метода `read_csv()`, в него нужно передать список с названием полей-дат, и в большинстве случаев дата будет корректно преобразована в нужный формат сразу:)
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Спасибо за информацию, буду иметь ввиду, если будет возникать ошибка)</div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Пользуйся на здоровье:)

# %%
# Создадим функцию, которая выведет информацию, пропуски, дубликаты по датафреймам 
def information(df):
    df.info()
    print("\nКоличество пропущенных значений:\n", df.isna().sum().sum())
    print("\nКоличество дубликатов в датафрейме:", df.duplicated().sum())

# %%
# Выведем информацию по тренировочному датафрейму 
information(train_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14149 entries, 0 to 14148
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                14149 non-null  object
#  1   final.output.concentrate_ag                         14148 non-null  float64
#  2   final.output.concentrate_pb                         14148 non-null  float64
#  3   final.output.concentrate_sol                        13938 non-null  float64
#  4   final.output.concentrate_au                         14149 non-null  float64
#  5   final.output.recovery                               14149 non-null  float64
#  6   final.output.tail_ag                                14149 non-null  float64
#  7   final.output.tail_pb                                14049 non-null  float64
# ...

# %%
# Выведем информацию по тестовому датафрейму 
information(test_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5290 entries, 0 to 5289
# Data columns (total 53 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   date                                        5290 non-null   object
#  1   primary_cleaner.input.sulfate               5286 non-null   float64
#  2   primary_cleaner.input.depressant            5285 non-null   float64
#  3   primary_cleaner.input.feed_size             5290 non-null   float64
#  4   primary_cleaner.input.xanthate              5286 non-null   float64
#  5   primary_cleaner.state.floatbank8_a_air      5290 non-null   float64
#  6   primary_cleaner.state.floatbank8_a_level    5290 non-null   float64
#  7   primary_cleaner.state.floatbank8_b_air      5290 non-null   float64
#  8   primary_cleaner.state.floatbank8_b_level    5290 non-null   float64
# ...

# %%
# Выведем информацию по исходному датафрейму 
information(full_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19439 entries, 0 to 19438
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                19439 non-null  object
#  1   final.output.concentrate_ag                         19438 non-null  float64
#  2   final.output.concentrate_pb                         19438 non-null  float64
#  3   final.output.concentrate_sol                        19228 non-null  float64
#  4   final.output.concentrate_au                         19439 non-null  float64
#  5   final.output.recovery                               19439 non-null  float64
#  6   final.output.tail_ag                                19438 non-null  float64
#  7   final.output.tail_pb                                19338 non-null  float64
# ...

# %% [markdown]
# **Вывод:** Во всех таблицах наблюдаются пропущенные значения, также в таблицах с датами формат указан object, а не datatime. Таким образом необходимо заполнить пропущенные значения, а также поменять формат в таблицах date.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>
#
# Данные осмотрели - отлично!

# %% [markdown]
# ### Предобработка данных

# %%
# Создадим функцию которая пройдется по таблицам date все датафреймов и изменит тип данных
def date_time(df, name):
    df[name] = pd.to_datetime(df[name], format='%Y-%m-%d %H:%M:%S')
    return df[name]

# %%
# Применим функцию к трем датафреймам
date_time(train_df, 'date');
date_time(test_df, 'date');
date_time(full_df, 'date');

# Выведем полученные результаты
print(train_df.date.head(1),'\n')
print(test_df.date.head(1),'\n')
print(full_df.date.head(1),'\n')
# Out:
# 0   2016-01-15
# Name: date, dtype: datetime64[ns]
#
# 0   2016-09-01 00:59:59
# Name: date, dtype: datetime64[ns]
#
# 0   2016-01-15
# Name: date, dtype: datetime64[ns]

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>
#
# Привели даты к нужному формату - хорошо.

# %% [markdown]
# Как сказано в задаче, данные индексируются датой и временем получения информации (признак date) и поэтому соседние по времени параметры часто похожи. Воспользуемся, при заполнении пропусков, методом fill, который заполнит нулевые значения данными, из предыдущего столбца или строки.

# %%
# Заменим пропущенные значения методом ffill, axis укажем ноль, чтобы замена происходила построчно
train_df = train_df.ffill(axis=0)
test_df = test_df.ffill(axis=0)
full_df = full_df.ffill(axis=0)

print('Количество пропущенных значений:', train_df.isna().sum().sum())
print('Количество пропущенных значений:', test_df.isna().sum().sum())
print('Количество пропущенных значений:', full_df.isna().sum().sum())
# Out:
# Количество пропущенных значений: 0
# Количество пропущенных значений: 0
# Количество пропущенных значений: 0

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Обработали пропуски с помощью стратегии заполнения `forward fill`, а также пояснили причину выбора такой стратегии - отлично!
# </div>

# %% [markdown]
# ### Нахождение MAE между полученными расчётами и значением признака

# %% [markdown]
# Проверим эффективность обогащения по формуле:
# ![Recovery_1576238822.jpg](attachment:Recovery_1576238822.jpg)
# Для этого вычислим её на обучающей выборке для признака rougher.output.recovery. Найдем MAE между полученными значениями и значением признака.
#
# ***Условные обозначения:***
# * C — доля золота в концентрате после флотации/очистки (rougher.output.concentrate_au);
# * F — доля золота в сырье/концентрате до флотации/очистки (rougher.input.feed_au);
# * T — доля золота в отвальных хвостах после флотации/очистки (rougher.output.tail_au).
# * Значение для расчета MAE (rougher.output.recovery)

# %%
# Произведем расчет эффективности обогощения 
c = train_df['rougher.output.concentrate_au']
f = train_df['rougher.input.feed_au']
t = train_df['rougher.output.tail_au']
recovery = ((c*(f-t))/(f*(c-t))) * 100
print(recovery)
# Out:
# 0        87.107763
# 1        86.843261
# 2        86.842308
# 3        87.226430
# 4        86.688794
#            ...
# 14144    89.574376
# 14145    87.724007
# 14146    88.890579
# 14147    89.858126
# 14148    89.514960
# Length: 14149, dtype: float64

# %%
# Вычислим MAE
print('Значение MAE:', mean_absolute_error(train_df['rougher.output.recovery'], recovery))
# Out:
# Значение MAE: 9.73512347450521e-15

# %% [markdown]
# **Вывод:** Полученное значение MAE имеет низкий показатель, а значит предсказания в среднем не отличаются от истинных значений.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Оценили `MAE` между исходным и расчётным значением эффективности обогащения и убедились, что эффективность обогащения рассчитана правильно - отлично!
# </div>

# %% [markdown]
# ### Анализ признаков, недоступные тестовой выборки

# %%
# Выведем признаки отсутсвующие в тестовой выборке. 
unavailable_tables = set(train_df.columns) - set(test_df.columns)

print('Пропущенные таблицы:')
unavailable_tables
# Out:
# Пропущенные таблицы:
# {'final.output.concentrate_ag',
#  'final.output.concentrate_au',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.recovery',
#  'final.output.tail_ag',
#  'final.output.tail_au',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_au',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_au',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
# ...

# %%
print('Количество отсутсвующих признаков:', len(unavailable_tables))
# Out:
# Количество отсутсвующих признаков: 34

# %% [markdown]
# **Вывод:**  В тестовой выборки отсутствуют 34 значения. Также в этом датафрейме отсутсвуют целевые признаки rougher.output.recovery и final.output.recovery необходимые для расчета метрики качества. Передадим значение из исходной выборки в тестовую с помощью merge. Совпадающим значением столбца будет date.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Проанализировали разницу в признаках между выборками.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# Как думаешь, почему в `train` есть признаки, которые недоступны в `test`?
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Как сказано в задаче некоторые параметры недоступны, потому что замеряются и/или рассчитываются значительно позже. Из-за этого в тестовой выборке отсутствуют некоторые признаки, которые могут быть в обучающей. Также в тестовом наборе нет целевых признаков. Поэтому наблюдается такая картина)</div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Отлично!

# %%
# Заполним целевыми значениями тестовую выборку из данных full_df
test_df = test_df.merge(full_df.loc[:,['date','rougher.output.recovery','final.output.recovery']], on='date')
test_df
# Out:
#                     date  primary_cleaner.input.sulfate  \
# 0    2016-09-01 00:59:59                     210.800909
# 1    2016-09-01 01:59:59                     215.392455
# 2    2016-09-01 02:59:59                     215.259946
# 3    2016-09-01 03:59:59                     215.336236
# 4    2016-09-01 04:59:59                     199.099327
# ...                  ...                            ...
# 5285 2017-12-31 19:59:59                     173.957757
# 5286 2017-12-31 20:59:59                     172.910270
# 5287 2017-12-31 21:59:59                     171.135718
# 5288 2017-12-31 22:59:59                     179.697158
# 5289 2017-12-31 23:59:59                     181.556856
#
#       primary_cleaner.input.depressant  primary_cleaner.input.feed_size  \
# 0                            14.993118                         8.080000
# 1                            14.987471                         8.080000
# 2                            12.884934                         7.786667
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В `test` добавили целевые признаки из `full`, используя дату как ключ при соединении - отлично!

# %%
# Удалим дату для тренерованой и тестовой выборки, так как она может помешать обучению модели
train_df = train_df.drop('date', axis=1)
test_df = test_df.drop('date', axis=1)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Удаляем даты - порядок!

# %% [markdown]
# **Вывод:** Предобработка приведена, пустые значения заполнены, удалены даты из тренировочной и тестовой выборки, найдено количество пропущенных признаков в тестовой выборке (34 шт), добавлены целевые признаки в тестовый датафрейм.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Есть промежуточный вывод - отлично!

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ###  Изменения концентрации металлов (Au, Ag, Pb) на различных этапах очистки

# %% [markdown]
# Построим графики для наглядного представления изменения концентрации металлов (Au, Ag, Pb) на различных этапах очистки.

# %%
position = 0
plt.figure(figsize=[15, 17])

plt.subplots_adjust(top=0.94, wspace=0.2, hspace=0.3)
plt.suptitle('График концентрации металлов на различных этапах очистки.', fontsize=22)

# Создадим цикл, который пройдется по списку значений и построит графики
for metal in ['au', 'ag', 'pb']:
    position += 1
    plt.subplot(3, 1, position)
    plt.title(f'График распределения {metal} на различных этапах очистки', fontsize=16)
    
    # Добавим сетку к графикам
    sns.set_style('whitegrid')
    
    # Добавим значения, которые будут распологаться на графике 
    sns.histplot(train_df[f'rougher.input.feed_{metal}'], 
                 color='tomato', label='Сырье')
    sns.histplot(train_df[f'rougher.output.concentrate_{metal}'], 
                 color='magenta', label='Концентрация после флотации')
    sns.histplot(train_df[f'primary_cleaner.output.concentrate_{metal}'], 
                 color='cyan', label='Концентрация после первичной очистки')
    sns.histplot(train_df[f'final.output.concentrate_{metal}'], 
                 color='lawngreen', label='Финальная концетрация металла')
    plt.xlabel('Концентрация металла', fontsize=12)
    plt.ylabel('Количество наблюдений', fontsize=12)
    plt.legend()
plt.show();

# %% [markdown]
# **Вывод:** В ходе анализа графиков стоит отметить, что концентрация металлов на этапах очистки для:
# * Золота (au) увеличивается на финальном этапе очистки
# * Серебра (ag) увеличивается на флотационном этапе очистки
# * Свинйа (pb) увеличивается после первичной очистки
#
# Также во всех данных присутвуют аномальные значения

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Исследована концентрация металлов на разных стадиях обработки, проанализирована динамика концентрации в зависимости от этапа техпроцесса - отлично, тут всё верно.
#
# Круто, что заметил нулевые значения на графике концентрации - это действительно аномалия, подлежащая удалению.
# </div>

# %% [markdown]
# ### Сравнение распределения размеров гранул сырья на обучающей и тестовой выборках

# %% [markdown]
# Построим графики для наглядного представления распределения гранул

# %%
position = 0
plt.figure(figsize = [15, 17])

plt.subplots_adjust(top=0.94, wspace=0.2, hspace=0.2)
plt.suptitle('Сравнение распределения размеров гранул сырья на обучающей и тестовой выборках', fontsize=22)

# Создадим цикл, который пройдется по необходимым значениям и построит графики
for concentration in ['rougher', 'primary_cleaner']:
    position+= 1
    plt.subplot(2, 1, position)
    plt.title(f'Распределение гранул на этапе {concentration} в обчающей и тестовой выборках', fontsize=15)
    
    sns.set_style('whitegrid')
    
    plt.hist(train_df[f'{concentration}.input.feed_size'], 
                 color='indigo', label='Сырье обучающей выборки', density=True)
    plt.hist(test_df[f'{concentration}.input.feed_size'],
                 color='gold', label='Сырье тренировочной выборки', density=True)
    plt.xlabel('Размеры гранул')
    plt.ylabel('Количество наблюдений')
    plt.legend()
plt.show();

# %% [markdown]
# **Вывод:** Количество наблюдений на этапе флотации (rougher) в тренировочной и тестовой выборках отличаются. Для тренировочной выборки по наблюдениям преобладают размеры гранул в районе 50. В обучающей выборке преобладают размеры меньше и больше 50. На этапе первичной очистки (primary_cleaner) количество наблюдений в обучающей выборки больше, чем в тренеровочной. В целом распределения гранул по размерам находятся в одном диапозоне, поэтому значимых различий между распределениями для выборок не наблюдается.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Сравнили размеры гранул сырья на обучающей и тестовой выборках для этапов `rougher.input.feed_size` и `primary_cleaner.input.feed_size` - отлично, распределения между выборками действительно схожи, следовательно модель будет корректно работать.
#
# Здорово, что используешь гистограмму плотности для оценки распределения непрерывных переменных.
# </div>

# %% [markdown]
# ### Исследование суммарной концентрации всех веществ на разных стадиях

# %%
# Создадим переменные, в которые сохраним сумму получившихся значений  
# Суммарная концентрация в сырье:
sum_concentrate_of_rougher_input = 0
# Суммарная концентрация в черновой концентрации
sum_concentrate_of_rougher_output = 0
# Суммарная концентрация в финальной концентрации
sum_concentrate_of_final_output = 0

# Создадим цикл, который посчитает сумму всех веществ и сохранит его в переменные
for metal in ['au', 'ag', 'pb', 'sol']:
    sum_concentrate_of_rougher_input += train_df[f'rougher.input.feed_{metal}']
    sum_concentrate_of_rougher_output += train_df[f'rougher.output.concentrate_{metal}']
    sum_concentrate_of_final_output += train_df[f'final.output.concentrate_{metal}']

# %%
plt.figure(figsize = [15, 10])
plt.title(f'График суммарной концентрации всех веществ на разных стадиях', fontsize=16)

# Добавим сетку к графикам
sns.set_style('whitegrid')
    
# Добавим значения, которые будут распологаться на графике 
sns.histplot(sum_concentrate_of_rougher_input, 
             color='navy', label='Концентрация в сырье', kde=False)

sns.histplot(sum_concentrate_of_rougher_output, 
             color='cadetblue', label='Концентрация после флотации')

sns.histplot(sum_concentrate_of_final_output, 
             color='purple', label='Финальная концетрация')

plt.xlabel('Концентрация веществ', fontsize=12)
plt.ylabel('Количество наблюдений', fontsize=12)
plt.legend()
plt.show();

# %% [markdown]
# **Вывод:** Количество веществ увеличивается после проведения флотации и финального этапа. Стоит отметить, что на финальном этапе и этапе флотации присутствуют аномальные значения, которые могут помешать дальнейшему обучению качества модели. Отсеим значения равные 0.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Исследована суммарная концентрация металлов на разных стадиях техпроцесса - отлично! Также отмечено наличие нулевых значений и необходимость их удаления - тут всё круто!
# </div>

# %%
# Отсеим значения равные нулю с помощью цикла
for stage in ['rougher', 'final']:
    train_df = train_df[(train_df[f'{stage}.output.concentrate_au'] != 0) & 
                    (train_df[f'{stage}.output.concentrate_ag'] != 0) & 
                    (train_df[f'{stage}.output.concentrate_pb'] != 0) & 
                    (train_df[f'{stage}.output.concentrate_sol'] != 0)]
    
    full_df = full_df[(full_df[f'{stage}.output.concentrate_au'] != 0) & 
                    (full_df[f'{stage}.output.concentrate_ag'] != 0) & 
                    (full_df[f'{stage}.output.concentrate_pb'] != 0) & 
                    (full_df[f'{stage}.output.concentrate_sol'] != 0)]

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Отбросили строки с нулевым значением суммарной концентрации из тренировочной и полной выборки - супер!
# </div>

# %% [markdown]
# **Вывод:** В результате проведенных анализов концентрация металлов на этапах очистки увеличивается. Распределения гранул по размерам находятся в одном диапозоне, при этом количество наблюдений на этапе флотации у тренеровачной и тестовой выборке разное. Количество различных веществ увеличивается по мере прохождения различных этапов очистки. В данных выявлены и удалены аномальные значения, влияющие на качество модели.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Есть вывод - супер!

# %% [markdown]
# ## Модель

# %% [markdown]
# ### Функция для вычисления итоговой sMAPE

# %% [markdown]
# Формула SMAPE:
# ![image.png](attachment:image.png)
# Формула итогового SMAPE:
# ![image-2.png](attachment:image-2.png)

# %%
# Напишим формулу SMAPE через функцию def
def calculation_smape(x, y):
    smape = (1/len(x))*np.sum((np.abs(x - y))/( (np.abs(x)+np.abs(y))/2))*100
    return smape

# %%
# Напишем формулу итогового SMAPE
def final_smape_function(rougher, final):
    final = 0.25*rougher+0.75*final
    return final

# %% [markdown]
# Необходимо найти минимальные значения, то есть при которых модель должна показать не максимальные значения, а минимальные значения, так при использовании функций cross_val_score, GridSearchCV и RandomizedSearchCV, результаты вычеслений имеют максимальные значения, то есть чем больше значения метрики, тем лучше. Но при использовании make_scorer, если указать (greater_is_better = False), фактические значения метрики домножится на -1. Это отразится в результатах выполнения функций cross_val_score, GridSearchCV и RandomizedSearchCV (значения будут отрицательными). В результате таких монипуляций лучшей моделью будет та, у которой будут минимальные значения

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
# Мысль как будто бы обрывается - возможно, стоит закончить предложение.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
smape_scorer = make_scorer(calculation_smape, greater_is_better = False)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Есть функции для частного и взвешенного `sMAPE`, а также пользовательский скорринг для кросс-валидации - супер!
# </div>

# %% [markdown]
# ### Разделение данных

# %%
unnecessary_signs = unavailable_tables- set(['rougher.output.recovery','final.output.recovery'])
print('Признаки, отсутсвующие в тестовой выборке:', len(unnecessary_signs))
# Out:
# Признаки, отсутсвующие в тестовой выборке: 32

# %%
# Удалим этим признаки из тренировачной выборке, чтобы модель смогла обучиться на тестевой выборке
train_df = train_df.drop(columns=unnecessary_signs, axis=1)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Синхронизировали тренировочную и тестовую выборки по набору признаков - хорошо!
# </div>

# %%
# Подготовим данные для изучения модели
features_train = train_df.drop(['rougher.output.recovery','final.output.recovery'], axis=1)
target_rougher_train = train_df['rougher.output.recovery']
target_final_train = train_df['final.output.recovery']

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Выделили признаки для обучения и целевые признаки - отлично!
# </div>

# %%
# %%time
# Обучим модель на тренировочной выборке в этапе флотации
model_lr_rougher = LinearRegression()
smape_rougher = cross_val_score(model_lr_rougher,
                                features_train,
                                target_rougher_train,
                                scoring = smape_scorer,
                                cv=5)
# Получим среднее значения и сохраним их в final_smape_rougher
final_smape_rougher = smape_rougher.mean()

# Обучим модель на тренировочной выборке в финальном этапе 
model_lr_final = LinearRegression()
smape_final = cross_val_score(model_lr_final,
                              features_train,
                              target_final_train,
                              scoring = smape_scorer,
                              cv=5)
final_smape_final = smape_final.mean()
# Умоножим полученный результат на -1, так через прохождения make score значения домножаются на -1
result_smape = final_smape_function(final_smape_rougher, final_smape_final)*(-1)
print('Результат логистической регрессии:', result_smape)
# Out:
# Результат логистической регрессии: 10.059261443482796
# CPU times: user 1.47 s, sys: 1.66 s, total: 3.13 s
# Wall time: 3.06 s

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Оценили линейную регрессию на кросс-валидации - отлично!
# </div>

# %%
# state = RandomState(12345)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# Использование `np.random.RandomState` нужно в тех случаях, когда сэмплы данных при каждом запуске должны получаться разными. Чтобы результаты твоих исследований были воспроизводимы, нужно использовать константу для параметров модели `random_state`.
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Исправил</div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
# %%time
best_result_dt = 100
best_param_dt = 0
for n in range(1, 10, 1):
    model_dt_rougher = DecisionTreeRegressor(max_depth=n, random_state=123)
    smape_rougher = cross_val_score(model_dt_rougher,
                                    features_train,
                                    target_rougher_train,
                                    scoring = smape_scorer,
                                    cv=5)
    final_smape_rougher = smape_rougher.mean()

    model_dt_final = DecisionTreeRegressor(max_depth=n, random_state=123)
    smape_final = cross_val_score(model_dt_final, 
                                  features_train,
                                  target_final_train,
                                  scoring = smape_scorer,
                                  cv=5)
    final_smape_final = smape_final.mean()
# Умоножим полученный результат на -1, так через прохождения make score значения домножаются на -1 
    result_smape = final_smape_function(final_smape_rougher, final_smape_final)*(-1)
    if result_smape < best_result_dt:
        best_result_dt = result_smape
        best_param_dt = n
print('Результат дерева решений:', best_result_dt)
print('Лучший параметр:', best_param_dt)
# Out:
# Результат дерева решений: 8.92578545203095
# Лучший параметр: 3
# CPU times: user 23.8 s, sys: 53.2 ms, total: 23.8 s
# Wall time: 24 s

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Для дерева решений оптимизировали гиперпараметры и оценили модель на кросс-валидации - отлично!
# </div>

# %%
# %%time
best_model_rf = 100
best_param_rf = 0
for n in range(10, 30, 20):
    for d in range(2,10,2):
        model_rf_rougher = RandomForestRegressor(n_estimators=n, max_depth=d, random_state=123)
        smape_rougher = cross_val_score(model_rf_rougher,
                                  features_train,
                                  target_rougher_train,
                                  scoring = smape_scorer,
                                  cv=5)
        final_smape_rougher = smape_rougher.mean()

        model_rf_final = RandomForestRegressor(n_estimators=n, max_depth=d, random_state=123)
        smape_final = cross_val_score(model_rf_final,
                                  features_train,
                                  target_final_train,
                                  scoring = smape_scorer,
                                  cv=5)
        final_smape_final = smape_final.mean()
        result_smape = final_smape_function(final_smape_rougher, final_smape_final)*(-1)
        if result_smape < best_model_rf:
            best_model_rf = result_smape
            best_param_rf = [n,d]
            
print('Результат случайного леса:', best_model_rf)
print('Лучшие параметры:', best_param_rf)
# Out:
# Результат случайного леса: 8.385299412518066
# Лучшие параметры: [10, 4]
# CPU times: user 1min 3s, sys: 231 ms, total: 1min 3s
# Wall time: 1min 3s

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Для случайного леса оптимизировали гиперпараметры и оценили модель на кросс-валидации - отлично!
# </div>

# %% [markdown]
# **Вывод:** Лучшие минимальные параметры у дерева решений, применим их на тестовой выборке.

# %%
# Подготовим данные для изучения модели
features_test = test_df.drop(['rougher.output.recovery','final.output.recovery'], axis=1)
target_rougher_test = test_df['rougher.output.recovery']
target_final_test = test_df['final.output.recovery']

# %%
# Обучим модель на тренировочных данных в этапе флотации
model_rougher = RandomForestRegressor(n_estimators=10, max_depth=8, random_state=123)
model_rougher.fit(features_train, target_rougher_train)
predicted_rougher = model_rougher.predict(features_test)

# Обучим модель на тренировочных данных в финальном этапе
model_final = RandomForestRegressor(n_estimators=10, max_depth=8, random_state=123)
model_final.fit(features_train, target_final_train)
predicted_final = model_final.predict(features_test)

smape_test_rougher = calculation_smape(target_rougher_test, predicted_rougher)
smape_test_final = calculation_smape(target_final_test, predicted_final)
final_smape_test = final_smape_function(smape_test_rougher, smape_test_final)
print('Полученный результат на тестовой выборке:', final_smape_test)
# Out:
# Полученный результат на тестовой выборке: 9.305321106913658

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Итоговую модель протестировали на тестовой выборке - отличный результат!
# </div>

# %%
# Проверим модель на адекватность 
dummy_rougher = DummyRegressor(strategy="mean")
dummy_final = DummyRegressor(strategy="mean")

# Обучим модель на тренировочных данных 
dummy_rougher.fit(features_train, target_rougher_train)
dummy_final.fit(features_train, target_final_train)

dummy_predicted_rougher = dummy_rougher.predict(features_test)
dummy_predicted_final = dummy_final.predict(features_test)

smape_const_rougher = calculation_smape(target_rougher_test, dummy_predicted_rougher)
smape_const_final = calculation_smape(target_final_test, dummy_predicted_final)

final_smape_const =  final_smape_function(smape_const_rougher, smape_const_final)
print('Полученный результат SMAPE для константной модели', final_smape_const)
# Out:
# Полученный результат SMAPE для константной модели 9.82146839182027

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Очень важно также проверить лучшую модель на адекватность, сравнив качество её предсказаний с качеством модели, которая предсказывала бы константу - вдруг окажется, что не было бы большого смысла заниматься созданием новых признаков, тюнингом и кросс-валидацией моделей, если можно было бы просто предсказывать среднее значение тренировочной выборки?
#
# В качестве константной модели можно использовать `DummyRegressor` (https://scikit-learn.org/stable/modules/generated/sklearn.dummy.DummyRegressor.html) -  эта модель как раз создана для генерирования константных предсказаний.
#
# Важно, чтобы результат тестирования нашей модели на тествой выборке был лучше, чем результат константной модели - в противном случае наша модель является бесполезной, так как все наши усилия над проектом не принесли результата, а можель, просто предсказывющая среднее на `train`, делает нашу работу лучше.
#         </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# **Вывод:** Была проведенна дополнительная предобработка, в которой были удалены признаки из тренеровачной выборке, мешающие обучению тестовой выборке. Лучшая модель на тренировочных данных оказалась RandomForestRegressor. Результат на тестовой выборке равен 9.3. В целом в ходе проведенного анализа можно отметить по мере прохождения доля золота и свинца увеличивается, а серебро уменьшается. Также проведена проверка модели на адекватность, в ходе, которой полученный результат оказался равен 9.83. Результат получился хуже чем в тестовой выборке, а значит модель имеет хорошее качество предсказания результатов.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Есть итоговый вывод по проекту - отлично!
# </div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: общий вывод по проекту.
#
# Кирилл, проект получился на довольно хорошем уровне - ты хорошо постарался, молодец!
#
# Мне нравится твой аналитический подход к выполнению проекта, ты соблюдаешь структуру работы, выполняешь её последовательно - это очень хорошо! Шаги проекта выполнены по порядку согласно плану проекта, нет смысловых и структурных ям. Важно, что не забываешь про выводы.
#
# Работа с моделями также выполнена отлично: исследовано несколько алгоритмов, проведён подбор гиперпараметров с помощью `GridSearchCV`, выполнена промежуточная оценка моделей на кросс-валидации - молодец!
#
# Над проектом ещё стоит поработать - есть рекомендации по дополнению некоторых твоих шагов проекта. Такие рекомендации я отметил жёлтыми комментариями. Будет здорово, если ты учтёшь их - так проект станет структурно и содержательно более совершенным.
#
# Также в работе есть критические замечания. К этим замечаниям я оставил пояснительные комментарии красного цвета, в которых перечислил возможные варианты дальнейших действий. Уверен, ты быстро с этим управишься:)
#
# Если о том, что нужно сделать в рамках комментариев, будут возникать вопросы - оставь их, пожалуйста, в комментариях, и я отвечу на них во время следующего ревью.
#
# Также буду рад ответить на любые твои вопросы по проекту или на какие-либо другие, если они у тебя имеются - оставь их в комментариях, и я постараюсь ответить:)
#
# Жду твой проект на повторном ревью. До встречи:)

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: общий вывод по проекту v.2.
#
# Кирилл, все замечания учтены - проект принят!
#
# Спасибо за качественную работу над проектом, желаю успехов в дальнейшем обучении:)
